# %% [markdown]
# [Solution Lecture](https://youtu.be/V9QPBMvtrVs)
#
# [View in Colaboratory](https://colab.research.google.com/github/schwaaweb/aimlds1_07-TheMachineLearningFramework/blob/master/W07_AS--RA--The_Machine_Learning_Framework_Solution.ipynb)

# %%
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestRegressor

train_url = 'https://raw.githubusercontent.com/ryanleeallred/churn-data/master/train.csv'
train = pd.read_csv(train_url)

# We're not even going ot mess with the test dataset until we have a ROC_AUC score that's good. 
test_url = 'https://raw.githubusercontent.com/ryanleeallred/churn-data/master/test.csv'
test = pd.read_csv(test_url)

print(train.shape)
train.head()
# Out:
# /Users/darwinm/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# (2222, 22)
#      id state  account_length area_code     phone international_plan  \
# 0  3200    CT             100       510  416-1536                yes
# 1  2129    CT             146       408  380-3329                 no
# 2   598    AZ              84       415  341-2360                 no
# 3  2507    VT              43       408  331-8713                 no
# 4  1248    PA             101       415  368-2074                  ?
#
#   vmail_plan  vmail_message  day_mins  day_calls  ...  eve_calls eve_charge  \
# 0         no              0     107.2         98  ...        122       7.38
# 1        yes             23     149.6         96  ...        124      20.38
# 2         no              0     159.0         80  ...        128      14.27
# 3         no              0     135.8        125  ...         88      13.87
# 4         no              0     193.7        108  ...          ?      15.86
#
#   night_mins  night_calls  night_charge  intl_mins intl_calls  intl_charge  \
# 0      156.2          117          7.03        9.7          4         2.62
# 1      293.5          135         13.21        7.4          4            2
# 2      167.6          101          7.54       12.3          5         3.32
# 3      229.8          106         10.34       12.6          ?          3.4
# 4      223.0          100             ?       11.6          8         3.13
#
#   custserv_calls churn
# 0              1     0
# 1              2     0
# 2              1     0
# 3              0     0
# 4              0     0
#
# [5 rows x 22 columns]

# %%
# Change "no", "yes", to corresponding 0, 1 values.

train["international_plan"].replace(('yes', 'no'), (1, 0), inplace=True)
train["vmail_plan"].replace(('yes', 'no'), (1, 0), inplace=True)

pd.options.display.max_columns = None

train.head()
# Out:
#      id state  account_length area_code     phone international_plan  \
# 0  3200    CT             100       510  416-1536                  1
# 1  2129    CT             146       408  380-3329                  0
# 2   598    AZ              84       415  341-2360                  0
# 3  2507    VT              43       408  331-8713                  0
# 4  1248    PA             101       415  368-2074                  ?
#
#   vmail_plan  vmail_message  day_mins  day_calls day_charge eve_mins  \
# 0          0              0     107.2         98      18.22     86.8
# 1          1             23     149.6         96      25.43    239.8
# 2          0              0     159.0         80      27.03    167.9
# 3          0              0     135.8        125      23.09    163.2
# 4          0              0     193.7        108      32.93    186.6
#
#   eve_calls  eve_charge  night_mins  night_calls night_charge  intl_mins  \
# 0       122        7.38       156.2          117         7.03        9.7
# 1       124       20.38       293.5          135        13.21        7.4
# 2       128       14.27       167.6          101         7.54       12.3
# 3        88       13.87       229.8          106        10.34       12.6
# 4         ?       15.86       223.0          100            ?       11.6
#
#   intl_calls intl_charge  custserv_calls  churn
# 0          4        2.62               1      0
# 1          4           2               2      0
# 2          5        3.32               1      0
# 3          ?         3.4               0      0
# 4          8        3.13               0      0

# %%
# This will take all non-numeric values and force them to be NaNs will probably lose a small amount of data here.
train = train.apply(pd.to_numeric, errors='coerce')
print(train.dtypes)
# Out:
# id                      int64
# state                 float64
# account_length          int64
# area_code             float64
# phone                 float64
# international_plan    float64
# vmail_plan            float64
# vmail_message           int64
# day_mins              float64
# day_calls               int64
# day_charge            float64
# eve_mins              float64
# eve_calls             float64
# eve_charge            float64
# night_mins            float64
# night_calls             int64
# night_charge          float64
# intl_mins             float64
# intl_calls            float64
# intl_charge           float64
# custserv_calls          int64
# churn                   int64
# dtype: object

# %%
# Fill NaN values with mean column values

train.fillna(train.mean(), inplace=True)

# Count the number of NaN values in each column

print(train.isnull().sum())
# Out:
# id                       0
# state                 2222
# account_length           0
# area_code                0
# phone                 2222
# international_plan       0
# vmail_plan               0
# vmail_message            0
# day_mins                 0
# day_calls                0
# day_charge               0
# eve_mins                 0
# eve_calls                0
# eve_charge               0
# night_mins               0
# night_calls              0
# night_charge             0
# intl_mins                0
# intl_calls               0
# intl_charge              0
# custserv_calls           0
# churn                    0
# dtype: int64

# %%
# Drop dolumns that I don't want to deal with rn.
train = train.drop('area_code', axis=1)
train = train.drop('phone', axis=1)
train = train.drop('state', axis=1)

print(train.shape)
train.head(10)
# Out:
# (2222, 19)
#      id  account_length  international_plan  vmail_plan  vmail_message  \
# 0  3200             100            1.000000         0.0              0
# 1  2129             146            0.000000         1.0             23
# 2   598              84            0.000000         0.0              0
# 3  2507              43            0.000000         0.0              0
# 4  1248             101            0.093617         0.0              0
# 5  2582             116            0.000000         0.0              0
# 6  2359              71            0.000000         1.0             31
# 7  2224              68            0.000000         0.0              0
# 8  1661              92            0.000000         1.0             38
# 9  2895              33            1.000000         0.0              0
#
#    day_mins  day_calls  day_charge  eve_mins   eve_calls  eve_charge  \
# 0     107.2         98       18.22      86.8  122.000000        7.38
# 1     149.6         96       25.43     239.8  124.000000       20.38
# 2     159.0         80       27.03     167.9  128.000000       14.27
# 3     135.8        125       23.09     163.2   88.000000       13.87
# 4     193.7        108       32.93     186.6   99.797225       15.86
# 5     205.0         90       34.85     140.9  114.000000       11.98
# 6     115.4         90       19.62     217.4   78.000000       18.48
# 7     143.6         80       24.41     134.3   65.000000       11.42
# 8     242.2         96       41.17     159.7  144.000000       13.57
# 9     164.0         99       27.88     153.1  102.000000       13.01
#
#    night_mins  night_calls  night_charge  intl_mins  intl_calls  intl_charge  \
# 0       156.2          117      7.030000        9.7    4.000000         2.62
# 1       293.5          135     13.210000        7.4    4.000000         2.00
# 2       167.6          101      7.540000       12.3    5.000000         3.32
# 3       229.8          106     10.340000       12.6    4.504244         3.40
# 4       223.0          100      8.982913       11.6    8.000000         3.13
# 5       272.6           96      8.982913        7.5    4.000000         2.03
# 6       239.9          102      8.982913       13.1    4.000000         3.54
# 7       215.6           84      9.700000       15.5    5.000000         4.19
# 8       210.0          108      9.450000        8.9    1.000000         2.40
# 9       123.8          104      8.982913        6.4    4.000000         1.73
#
#    custserv_calls  churn
# 0               1      0
# 1               2      0
# 2               1      0
# 3               0      0
# 4               0      0
# 5               2      0
# 6               1      0
# 7               2      0
# 8               1      0
# 9               0      0

# %%
# Generate independent and dependent vars
Y = train['churn']
X = train.drop(['churn'], axis=1)

X.head()
# Out:
#      id  account_length  international_plan  vmail_plan  vmail_message  \
# 0  3200             100            1.000000         0.0              0
# 1  2129             146            0.000000         1.0             23
# 2   598              84            0.000000         0.0              0
# 3  2507              43            0.000000         0.0              0
# 4  1248             101            0.093617         0.0              0
#
#    day_mins  day_calls  day_charge  eve_mins   eve_calls  eve_charge  \
# 0     107.2         98       18.22      86.8  122.000000        7.38
# 1     149.6         96       25.43     239.8  124.000000       20.38
# 2     159.0         80       27.03     167.9  128.000000       14.27
# 3     135.8        125       23.09     163.2   88.000000       13.87
# 4     193.7        108       32.93     186.6   99.797225       15.86
#
#    night_mins  night_calls  night_charge  intl_mins  intl_calls  intl_charge  \
# 0       156.2          117      7.030000        9.7    4.000000         2.62
# 1       293.5          135     13.210000        7.4    4.000000         2.00
# 2       167.6          101      7.540000       12.3    5.000000         3.32
# 3       229.8          106     10.340000       12.6    4.504244         3.40
# 4       223.0          100      8.982913       11.6    8.000000         3.13
#
#    custserv_calls
# 0               1
# 1               2
# 2               1
# 3               0
# 4               0

# %%
# Fit Random Forest Classifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

kfold = KFold(n_splits=3, random_state=42) 
scores = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='roc_auc')
print("Mean AUC Score - Random Forest: ", scores.mean())
# Out:
# Mean AUC Score - Random Forest:  0.8877240000187493

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
cross_val = KFold(n_splits=3, random_state=42)
scores = cross_val_score(model, X, Y, cv=cross_val, scoring='roc_auc')
print("Mean AUC Score - Logistic Regression: ", scores.mean())
# Out:
# Mean AUC Score - Logistic Regression:  0.7914651797821616

# %%
### Decision Tree
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier()
cross_val = KFold(n_splits=3, random_state=42)
scores = cross_val_score(model2, X, Y, cv=cross_val, scoring='roc_auc')
print("Mean AUC Score - Decision Tree: ", scores.mean())
# Out:
# Mean AUC Score - Decision Tree:  0.7924412056446318

# %%
### Naive Bayes
from sklearn.naive_bayes import GaussianNB
model4 = GaussianNB()
cross_val = KFold(n_splits=3, random_state=42)
scores = cross_val_score(model4, X, Y, cv=cross_val, scoring='roc_auc')
print("Mean AUC Score - Gaussian Naive Bayes: ", scores.mean())
# Out:
# Mean AUC Score - Gaussian Naive Bayes:  0.8298956230587861

# %%
### K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
model5 = KNeighborsClassifier()
cross_val = KFold(n_splits=3, random_state=42)
scores = cross_val_score(model5, X, Y, cv=cross_val, scoring='roc_auc')
print("Mean AUC Score - K-Nearest Neighbors: ", scores.mean())
# Out:
# Mean AUC Score - K-Nearest Neighbors:  0.5987537195869482

# %%
### Support Vector Machine
from sklearn.svm import SVC
model1 = SVC()
cross_val = KFold(n_splits=3, random_state=42)
scores = cross_val_score(model, X, Y, cv=cross_val, scoring='roc_auc')
print("Mean AUC Score - Support Vector Machine: ", scores.mean())
# Out:
# Mean AUC Score - Support Vector Machine:  0.7914651797821616

# %%
#test

# %%
# Lets clean the test data now.

test["international_plan"].replace(('yes', 'no'), (1, 0), inplace=True)
test["vmail_plan"].replace(('yes', 'no'), (1, 0), inplace=True)

test = test.apply(pd.to_numeric, errors='coerce')

test.fillna(test.mean(), inplace=True)

test = test.drop('area_code', axis=1)
test = test.drop('phone', axis=1)
test = test.drop('state', axis=1)

test.head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-f5c0efec6b5f> in <module>()
#       1 # Lets clean the test data now.
#       2
# ----> 3 test["international_plan"].replace(('yes', 'no'), (1, 0), inplace=True)
#       4 test["vmail_plan"].replace(('yes', 'no'), (1, 0), inplace=True)
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    4578                                                        dest_list=value,
#    4579                                                        inplace=inplace,
# -> 4580                                                        regex=regex)
#    4581
#    4582                 else:  # [NA, ''] -> 0
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in replace_list(self, src_list, dest_list, inplace, regex, mgr)
#    3485             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3486
# -> 3487         masks = [comp(s) for i, s in enumerate(src_list)]
#    3488
#    3489         result_blocks = []
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in <listcomp>(.0)
#    3485             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3486
# -> 3487         masks = [comp(s) for i, s in enumerate(src_list)]
#    3488
#    3489         result_blocks = []
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in comp(s)
#    3483             if isna(s):
#    3484                 return isna(values)
# -> 3485             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3486
#    3487         masks = [comp(s) for i, s in enumerate(src_list)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _maybe_compare(a, b, op)
#    4945             type_names[1] = 'ndarray(dtype=%s)' % b.dtype
#    4946
# -> 4947         raise TypeError("Cannot compare types %r and %r" % tuple(type_names))
#    4948     return result
#    4949
#
# TypeError: Cannot compare types 'ndarray(dtype=float64)' and 'str'

# %%
# Fit to the whole train dataset

RandomForest = RandomForestClassifier()
RandomForest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# and Predict on the test dataset

# Need to split test into X_test Y_test
Y_test = test['churn']
X_test = test.drop(['churn'], axis=1)

predicted_values = RandomForest.predict(X_test)

final_test = X_test
final_test['churn'] = 0
final_test['churn'] = predicted_values

final_test.head(30)
# Out:
#       id  account_length  international_plan  vmail_plan  vmail_message  \
# 0    221             127            0.000000    1.000000             22
# 1   1313             100            0.000000    0.000000              0
# 2   1635              66            0.000000    0.000000              0
# 3    289              89            0.000000    0.000000              0
# 4   2416             113            0.108108    0.000000              0
# 5   3112             115            0.108108    0.000000              0
# 6    601              62            1.000000    0.000000              0
# 7    326             121            0.108108    1.000000             35
# 8   2783              79            0.000000    1.000000             17
# 9    454              97            0.000000    0.000000              0
# 10   439              81            0.108108    0.000000              0
# 11  1783              85            0.000000    1.000000             29
# 12  2091              33            0.000000    0.000000              0
# 13  3082             130            0.000000    0.000000              0
# 14  2821             130            0.108108    0.000000              0
# 15  1345              98            0.000000    0.000000              0
# 16  2206              67            0.000000    0.000000              0
# 17  1557              52            0.108108    1.000000             32
# 18   483             117            0.000000    0.000000              0
# 19   795              92            0.000000    0.000000              0
# 20  3244             101            0.000000    0.000000              0
# 21  3219             150            0.108108    0.288119             35
# 22  1862             133            1.000000    0.000000              0
# 23   292              94            0.000000    0.000000              0
# 24  1898             159            0.000000    0.000000              0
# 25  3014             153            0.000000    0.000000              0
# 26   799             100            0.000000    1.000000             26
# 27  2347              68            1.000000    1.000000             29
# 28   763              33            0.000000    1.000000             35
# 29  2806              13            0.000000    0.000000              0
#
#     day_mins  day_calls  day_charge  eve_mins   eve_calls  eve_charge  \
# 0      166.0        114       28.22     174.5  103.000000       14.83
# 1      235.8        130       40.09     176.0  100.865815       14.96
# 2      154.0        133       26.18     198.9  121.000000       16.91
# 3      303.9         95       51.66     260.9  114.000000       22.18
# 4      156.0        141       26.52     256.8   72.000000       21.83
# 5      139.3         89       23.68     192.3   95.000000       16.35
# 6      159.7         86       27.15     197.5   76.000000       16.79
# 7       68.7         95       11.68     209.2   69.000000       17.78
# 8      167.9        114       28.54     243.7   93.000000       20.71
# 9      256.4        125       43.59     273.9  100.000000       23.28
# 10     153.5         99       26.10     197.6  102.000000       16.80
# 11     144.6         97       24.58     140.0  100.865815       11.90
# 12     182.5         65       31.03     232.1   96.000000       19.73
# 13     203.9         63       34.66     191.8  100.865815       16.30
# 14     252.0        101       42.84     170.2  100.865815       14.47
# 15       0.0          0        0.00     159.6  130.000000       13.57
# 16     176.2        120       29.95     236.0  100.865815       20.06
# 17     130.1         68       22.12     247.2   77.000000       21.01
# 18     149.9         95       25.48     256.1  110.000000       21.77
# 19     197.0         84       33.49     269.3  105.000000       22.89
# 20     231.3         87       39.32     224.7  100.865815       19.10
# 21     139.6         72       23.73     332.8  170.000000       28.29
# 22     254.7        103       43.30     252.2   80.000000       21.44
# 23     177.1        112       30.11     194.0  112.000000       16.49
# 24     275.8        103       46.89     189.5  108.000000       16.11
# 25     166.8        127       28.36     143.5  121.000000       12.20
# 26     153.7        115       26.13     137.8  146.000000       11.71
# 27     195.5        113       33.24     171.6   96.000000       14.59
# 28     186.8        124       31.76     261.0  100.865815       22.19
# 29     220.4        100       37.47     211.2  100.865815       17.95
#
#     night_mins  night_calls  night_charge  intl_mins  intl_calls  intl_charge  \
# 0        244.9           68     11.020000       10.2    6.000000     2.750000
# 1         63.6          122      2.860000        7.3    1.000000     1.970000
# 2        151.9          100      6.840000        9.5    3.000000     2.570000
# 3        312.1           89     14.040000        5.3    4.487832     1.430000
# 4        175.3          123      7.890000       11.9    5.000000     3.210000
# 5        151.0           75      6.800000        9.3    3.000000     2.510000
# 6        121.6          105      5.470000       13.9    6.000000     3.750000
# 7        197.4           42      8.880000       11.4    4.000000     3.080000
# 8        211.9          114      9.540000        9.1    2.000000     2.460000
# 9        222.7          101     10.020000       11.1    4.487832     3.000000
# 10       198.5           86      8.930000        6.3    2.000000     1.700000
# 11       165.4          148      7.440000       10.9    3.000000     2.940000
# 12       149.2           82      6.710000        7.5    2.000000     2.761964
# 13       132.5          125      5.960000       12.1    4.000000     3.270000
# 14       209.2           64      9.410000        5.7    4.487832     1.540000
# 15       167.1           88      7.520000        6.8    1.000000     2.761964
# 16       152.5          104      6.860000       10.6    4.000000     2.761964
# 17       289.4           87      9.146474       13.5    5.000000     3.650000
# 18       212.7           92      9.570000       13.3   13.000000     3.590000
# 19       158.9          105      7.150000       10.8    4.487832     2.920000
# 20       214.6           69      9.660000        7.2    7.000000     1.940000
# 21       213.8          105      9.620000        8.8    2.000000     2.761964
# 22       178.1          103      8.010000        8.0    3.000000     2.160000
# 23       146.7          108      6.600000        5.9    4.000000     1.590000
# 24       223.9           93     10.080000        7.4    5.000000     2.000000
# 25       210.7          130      9.480000       11.8    4.000000     3.190000
# 26       213.5          104      9.610000       15.9    5.000000     4.290000
# 27       204.0           85      9.180000       13.5    9.000000     3.650000
# 28       317.8          103     14.300000       15.0    5.000000     4.050000
# 29       259.3          112     11.670000       13.6    4.487832     3.670000
#
#     custserv_calls  churn
# 0                1      0
# 1                2      0
# 2                4      0
# 3                1      1
# 4                2      0
# 5                7      1
# 6                0      1
# 7                1      0
# 8                1      0
# 9                1      1
# 10               2      0
# 11               1      0
# 12               2      0
# 13               3      0
# 14               0      0
# 15               4      1
# 16               1      0
# 17               2      0
# 18               2      0
# 19               1      0
# 20               1      0
# 21               2      0
# 22               0      0
# 23               1      0
# 24               2      1
# 25               0      0
# 26               1      0
# 27               1      1
# 28               0      0
# 29               2      0

# %%
# Export final_test to csv

from google.colab import files

final_test.to_csv("ra_randomforest.csv", index = False)

files.download('ra_randomforest.csv')
